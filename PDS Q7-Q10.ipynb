# %%
import pandas as pd

# %%
df=pd.read_csv("C:\\Users\\4HIN\\Downloads\\imdb.csv")
df
# Out:
#                              fn        tid  \
# 0            titles01/tt0012349  tt0012349
# 1            titles01/tt0015864  tt0015864
# 2            titles01/tt0017136  tt0017136
# 3            titles01/tt0017925  tt0017925
# 4            titles01/tt0021749  tt0021749
# ...                         ...        ...
# 14756  titles04/index.html.9989  tt0672488
# 14757  titles04/index.html.9992  tt0675644
# 14758  titles04/index.html.9994  tt0679222
# 14759  titles04/index.html.9995  tt0680064
# 14760  titles04/index.html.9997  tt0681024
#
#                                                    title  \
# 0                       Der Vagabund und das Kind (1921)
# 1                                      Goldrausch (1925)
# 2                                      Metropolis (1927)
# 3                                     Der General (1926)
# 4                           Lichter der Großstadt (1931)
# ...                                                  ...
# ...

# %%
Q7

# %%
result = df.loc[4, 'imdbRating']
result
# Out:
# '8.7'

# %%
Q8

# %%
df['duration'] = pd.to_numeric(df['duration'], errors='coerce')
shortest_movie = df.loc[df['duration'].idxmin(), 'title']
longest_movie = df.loc[df['duration'].idxmax(), 'title']

print(f"Shortest movie: {shortest_movie}")
print(f"Longest movie: {longest_movie}")
# Out:
# Shortest movie: Traffic Crossing Leeds Bridge (1888)
# Longest movie: Scarface - Toni\

# %%
Q9

# %%
df['year'] = pd.to_datetime(df['year'], errors='coerce')
df['imdbRating'] = pd.to_numeric(df['imdbRating'], errors='coerce')
sorted_df = df.sort_values(by=['year', 'imdbRating'], ascending=[True, False])
sorted_df.reset_index(drop=True, inplace=True)

print(sorted_df)
# Out:
#                              fn        tid  \
# 0      titles03/index.html.3586  tt0322023
# 1      titles02/index.html.1970  tt1137936
# 2      titles03/index.html.1193  tt0063950
# 3      titles03/index.html.4523  tt0520589
# 4      titles03/index.html.4554  tt0566900
# ...                         ...        ...
# 14756  titles04/index.html.9737  tt0499516
# 14757  titles04/index.html.9748  tt0502664
# 14758  titles04/index.html.9751  tt0504240
# 14759   titles04/index.html.976  tt0040928
# 14760   titles04/index.html.984  tt0041085
#
#                                                    title  \
# 0                                                   Die\
# 1      Weeds - Kleine Deals unter Nachbarn If You Wor...
# 2                                            Scooby Doo\
# 3                                        Becker He Said\
# 4                       Duck Dodgers Of Course You Know\
# ...                                                  ...
# ...

# %%
Q10

# %%
df['duration'] = pd.to_numeric(df['duration'], errors='coerce')

# Subset the DataFrame for movies with duration between 30 minutes and 180 minutes
subset_df = df[(df['duration'] >= 1800) & (df['duration'] <= 10800)]

# Reset the index for better readability (optional)
subset_df.reset_index(drop=True, inplace=True)

# Display the subset DataFrame
print(subset_df)
